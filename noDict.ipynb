# %% [markdown]
# <a href="https://colab.research.google.com/github/walkerjian/dev/blob/main/noDict.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Given list of words
words = ["AL", "ANNA", "BAN", "BAY", "BULL", "CAR", "CAR", "HAVE", "JEERS", "JOULE", "KEY", "LEA", "LOW", "MAR", "MAY", "ROUTE", "SORE", "TOE", "TOMB", "WORE"]

# Create the concatenated pairs for each word
output_lists = {}

for word in words:
    concatenated_words = []
    for other_word in words:
        if word != other_word:
            concatenated_words.append(word + other_word)
    # Sort the list and store in the dictionary
    output_lists[word] = sorted(concatenated_words)

output_lists
# Out:
# {'AL': ['ALANNA',
#   'ALBAN',
#   'ALBAY',
#   'ALBULL',
#   'ALCAR',
#   'ALCAR',
#   'ALHAVE',
#   'ALJEERS',
#   'ALJOULE',
#   'ALKEY',
#   'ALLEA',
#   'ALLOW',
#   'ALMAR',
#   'ALMAY',
#   'ALROUTE',
#   'ALSORE',
#   'ALTOE',
#   'ALTOMB',
#   'ALWORE'],
#  'ANNA': ['ANNAAL',
#   'ANNABAN',
#   'ANNABAY',
#   'ANNABULL',
#   'ANNACAR',
#   'ANNACAR',
#   'ANNAHAVE',
#   'ANNAJEERS',
#   'ANNAJOULE',
#   'ANNAKEY',
#   'ANNALEA',
#   'ANNALOW',
#   'ANNAMAR',
#   'ANNAMAY',
#   'ANNAROUTE',
#   'ANNASORE',
#   'ANNATOE',
#   'ANNATOMB',
#   'ANNAWORE'],
#  'BAN': ['BANAL',
#   'BANANNA',
#   'BANBAY',
#   'BANBULL',
#   'BANCAR',
#   'BANCAR',
#   'BANHAVE',
#   'BANJEERS',
#   'BANJOULE',
#   'BANKEY',
#   'BANLEA',
#   'BANLOW',
#   'BANMAR',
#   'BANMAY',
#   'BANROUTE',
#   'BANSORE',
#   'BANTOE',
#   'BANTOMB',
#   'BANWORE'],
#  'BAY': ['BAYAL',
#   'BAYANNA',
#   'BAYBAN',
#   'BAYBULL',
#   'BAYCAR',
#   'BAYCAR',
#   'BAYHAVE',
#   'BAYJEERS',
#   'BAYJOULE',
# ...
